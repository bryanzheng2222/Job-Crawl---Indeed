# %% [markdown]
# <a href="https://colab.research.google.com/github/bryanzheng2222/Job-Crawl---Indeed/blob/main/Job%20crawl%20-%20Indeed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = 'https://careers.fbcareers.com/careers/SearchJobs/?3_171_3=0'

# %%
import requests

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'}

# %%
response = requests.get(url = url, headers = headers)
print (response.text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html>
#             <head><meta name='avature.portal.id' content='7'>
#             <meta http-equiv="content-type" content="text/html;charset=UTF-8" />
#             <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" />
#             <meta name="google-site-verification" content="NvwZpv15hXandc0CKRU0dZmmdrm7P-cbDWP3-AgnjI4" />
#                             <meta name="Description" content="Find Jobs Careers" />
#                                         <title>Find Jobs - Careers</title>
#                                         <link href="/portal/7/favicon.ico" rel="shortcut icon" id="favico" type="images/vnd.microsoft.icon">
#                                         <link rel="alternate" type="application/rss+xml" title="Find Jobs - Careers - RSS" href="https://careers.fbcareers.com/careers/SearchJobs/feed/" />
# ...

# %%
import requests
import re
import json
import pprint

# %%
html_data = re.findall('<div class="aluminium fr"> = (.*?) </div>', response.text)

# %%
print(html_data)
# Out:
# []

# %%
import re, matplotlib, random
from bs4 import BeautifulSoup
import pandas as pd
import seaborn as sns

# %%
pip install selenium
# Out:
# ...
#      |████████████████████████████████| 958 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 356 kB 55.3 MB/s
# ...
#      |████████████████████████████████| 138 kB 80.8 MB/s
# ...
#      |████████████████████████████████| 55 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 43.0 MB/s
# ...
#      |████████████████████████████████| 54 kB 4.2 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
from selenium import webdriver

# %%
Keywords = 'accounting'
page = 1
html_list =[]

# %%
for num in range (1,page,1):
  url = 'https://careers.fbcareers.com/careers/SearchJobs/accounting'.format(Keywords,num,num)
  driver = webdriver.Chrome()
  driver.get(url)
  time.sleep(8)
  htmls = driver.page_source
  html_list.append(str(htmls))
  driver.close()
  ran_time = random.randint(10,20)
  time.sleep(ran_time)
print(html_list)
# Out:
# []

# %%
job_list = []
for htmls in html_list:
  soup = BeautifulSoup(htmls)
for i in soup.find_all('div',class_="<li>"):
  job_unit_logo = i.find_all('div',class__="businessUnitLogo")
  job_title = i.find_all('div',class_="jobTitle")
